# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mortality-rate-in-the-usa-by-gender-area-cause/USRegionalMortality.csv

# %%
import pandas as pd

df = pd.DataFrame(pd.read_csv("/kaggle/input/mortality-rate-in-the-usa-by-gender-area-cause/USRegionalMortality.csv"))

df
# Out:
#      rownames         Region Status     Sex          Cause   Rate   SE
# 0           5  HHS Region 01  Urban    Male  Heart disease  188.2  1.0
# 1           6  HHS Region 01  Rural    Male  Heart disease  199.1  2.6
# 2           7  HHS Region 01  Urban  Female  Heart disease  115.1  0.6
# 3           8  HHS Region 01  Rural  Female  Heart disease  124.5  1.7
# 4           9  HHS Region 02  Urban    Male  Heart disease  226.8  0.8
# ..        ...            ...    ...     ...            ...    ...  ...
# 395       508  HHS Region 09  Rural  Female      Nephritis    8.4  0.5
# 396       509  HHS Region 10  Urban    Male      Nephritis    8.6  0.3
# 397       510  HHS Region 10  Rural    Male      Nephritis    8.6  0.5
# 398       511  HHS Region 10  Urban  Female      Nephritis    5.9  0.2
# 399       512  HHS Region 10  Rural  Female      Nephritis    6.7  0.4
#
# [400 rows x 7 columns]

# %%
keep_col = ['rownames','Rate','SE']
f = df[keep_col]
f.corr()
# Out:
#           rownames      Rate        SE
# rownames  1.000000 -0.773722 -0.543991
# Rate     -0.773722  1.000000  0.660344
# SE       -0.543991  0.660344  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
# draw lineplot
sns.lineplot(x="Cause", y="SE", data=df)
 
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
 
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
# draw lineplot
sns.lineplot(x="Cause", y="Rate", data=df)
 
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
 
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.scatterplot(x='Cause', y='SE', data=df,
               hue='Sex')
plt.show()

# %%
sns.scatterplot(x='Cause', y='SE', data=df,
               hue='Status')
plt.show()

# %%
sns.scatterplot(x='Cause', y='Rate', data=df,
               hue='Sex')
plt.show()

# %%
sns.scatterplot(x='Cause', y='Rate', data=df,
               hue='Status')
plt.show()

# %%
sns.scatterplot(x='Status', y='SE', data=df,
               hue='Cause')
plt.show()

# %%
sns.scatterplot(x='Sex', y='SE', data=df,
               hue='Cause')
plt.show()

# %%
sns.scatterplot(x='Status', y='Rate', data=df,
               hue='Cause')
plt.show()

# %%
sns.scatterplot(x='Sex', y='Rate', data=df,
               hue='Cause')
plt.show()

# %%
sns.scatterplot(x='SE', y='Region', data=df,
               hue='Cause')
plt.show()

# %%
sns.scatterplot(x='SE', y='Cause', data=df,
               hue='Region')
plt.show()

# %%
sns.scatterplot(x='Rate', y='Cause', data=df,
               hue='Region')
plt.show()

# %%
df = open("/kaggle/input/mortality-rate-in-the-usa-by-gender-area-cause/USRegionalMortality.csv", "r") 
  
df = ''.join([i for i in df])  
  
# search and replace the contents 
df = df.replace("Urban", "0")  
df = df.replace("Rural", "1")  
df = df.replace("Female", "0")  
df = df.replace("Male", "1")
df=df.replace("Heart disease","1")
df=df.replace("Cancer","2")
df=df.replace("Lower respiratory","3")
df=df.replace("Unintentional injuries","4")
df=df.replace("Cerebrovascular diseases","5")
df=df.replace("Alzheimers","6")
df=df.replace("Diabetes","7")
df=df.replace("Flu and pneumonia","8")
df=df.replace("Suicide","9")
df=df.replace("Nephritis","10")
df=df.replace("HHS Region 01","1")
df=df.replace("HHS Region 02","2")
df=df.replace("HHS Region 03","3")
df=df.replace("HHS Region 04","4")
df=df.replace("HHS Region 05","5")
df=df.replace("HHS Region 06","6")
df=df.replace("HHS Region 07","7")
df=df.replace("HHS Region 08","8")
df=df.replace("HHS Region 09","9")
df=df.replace("HHS Region 10","10")

# output.csv is the output file opened in write mode 
x = open("output.csv","w") 
  
# all the replaced text is written in the output.csv file 
x.writelines(df) 
x.close()

# %%
df=pd.DataFrame(pd.read_csv("/kaggle/working/output.csv"))

df
# Out:
#      rownames  Region  Status  Sex  Cause   Rate   SE
# 0           5       1       0    1      1  188.2  1.0
# 1           6       1       1    1      1  199.1  2.6
# 2           7       1       0    0      1  115.1  0.6
# 3           8       1       1    0      1  124.5  1.7
# 4           9       2       0    1      1  226.8  0.8
# ..        ...     ...     ...  ...    ...    ...  ...
# 395       508       9       1    0     10    8.4  0.5
# 396       509      10       0    1     10    8.6  0.3
# 397       510      10       1    1     10    8.6  0.5
# 398       511      10       0    0     10    5.9  0.2
# 399       512      10       1    0     10    6.7  0.4
#
# [400 rows x 7 columns]

# %%
df.corr()
# Out:
#           rownames        Region        Status           Sex         Cause  \
# rownames  1.000000  7.669436e-02  3.337694e-03 -6.675387e-03  9.970267e-01
# Region    0.076694  1.000000e+00 -6.957541e-18  3.169546e-17 -6.803985e-16
# Status    0.003338 -6.957541e-18  1.000000e+00  9.992007e-18  0.000000e+00
# Sex      -0.006675  3.169546e-17  9.992007e-18  1.000000e+00  8.743310e-16
# Cause     0.997027 -6.803985e-16  0.000000e+00  8.743310e-16  1.000000e+00
# Rate     -0.773722 -1.213286e-02  6.065431e-02  1.624568e-01 -7.742118e-01
# SE       -0.543991  5.427551e-02  5.151086e-01  1.824039e-01 -5.502910e-01
#
#               Rate        SE
# rownames -0.773722 -0.543991
# Region   -0.012133  0.054276
# Status    0.060654  0.515109
# Sex       0.162457  0.182404
# Cause    -0.774212 -0.550291
# Rate      1.000000  0.660344
# SE        0.660344  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df,hue='Cause')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df=pd.DataFrame(pd.read_csv("/kaggle/input/mortality-rate-in-the-usa-by-gender-area-cause/USRegionalMortality.csv"))

sns.pairplot(df,hue='Cause')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
d=df.loc[df['Cause'] == 'Heart disease']
d["rownames"].mean()
# Out:
# 24.5

# %%
d["Rate"].mean()
# Out:
# 176.71499999999997

# %%
d["SE"].mean()
# Out:
# 1.2449999999999999

# %%
d=df.loc[df['Cause'] == 'Cancer']
d["rownames"].mean()
# Out:
# 76.5

# %%
d["Rate"].mean()
# Out:
# 172.45499999999998

# %%
d["SE"].mean()
# Out:
# 1.2349999999999999

# %%
d=df.loc[df['Cause'] == 'Lower respiratory']
d["rownames"].mean()
# Out:
# 128.5

# %%
d["Rate"].mean()
# Out:
# 46.635000000000005

# %%
d["SE"].mean()
# Out:
# 0.6599999999999999

# %%
d=df.loc[df['Cause'] == 'Unintentional injuries']
d["rownames"].mean()
# Out:
# 180.5

# %%
d["Rate"].mean()
# Out:
# 45.135000000000005

# %%
d["SE"].mean()
# Out:
# 0.69

# %%
d=df.loc[df['Cause'] == 'Cerebrovascular diseases']
d["rownames"].mean()
# Out:
# 232.5

# %%
d["Rate"].mean()
# Out:
# 37.285000000000004

# %%
d["SE"].mean()
# Out:
# 0.5675

# %%
d=df.loc[df['Cause'] == 'Alzheimers']
d["rownames"].mean()
# Out:
# 284.5

# %%
d["Rate"].mean()
# Out:
# 23.917499999999997

# %%
d["SE"].mean()
# Out:
# 0.45

# %%
d=df.loc[df['Cause'] == 'Diabetes']
d["rownames"].mean()
# Out:
# 336.5

# %%
d["Rate"].mean()
# Out:
# 22.2875

# %%
d["SE"].mean()
# Out:
# 0.44000000000000006

# %%
d=df.loc[df['Cause'] == 'Flu and pneumonia']
d["rownames"].mean()
# Out:
# 388.5

# %%
d["Rate"].mean()
# Out:
# 16.18

# %%
d["SE"].mean()
# Out:
# 0.37749999999999995

# %%
d=df.loc[df['Cause'] == 'Suicide']
d["rownames"].mean()
# Out:
# 440.5

# %%
d["Rate"].mean()
# Out:
# 14.965

# %%
d["SE"].mean()
# Out:
# 0.4

# %%
d=df.loc[df['Cause'] == 'Nephritis']
d["rownames"].mean()
# Out:
# 492.5

# %%
d["Rate"].mean()
# Out:
# 13.492500000000001

# %%
d["SE"].mean()
# Out:
# 0.3425

# %%
d=df.loc[df['Region'] == 'HHS Region 01']
d["rownames"].mean()
# Out:
# 240.5

# %%
d["Rate"].mean()
# Out:
# 51.672500000000014

# %%
d["SE"].mean()
# Out:
# 0.7725

# %%
d=df.loc[df['Region'] == 'HHS Region 02']
d["rownames"].mean()
# Out:
# 244.5

# %%
d["Rate"].mean()
# Out:
# 54.647499999999994

# %%
d["SE"].mean()
# Out:
# 0.7900000000000001

# %%
d=df.loc[df['Region'] == 'HHS Region 03']
d["rownames"].mean()
# Out:
# 248.5

# %%
d["Rate"].mean()
# Out:
# 60.355

# %%
d["SE"].mean()
# Out:
# 0.6025

# %%
d=df.loc[df['Region'] == 'HHS Region 04']
d["rownames"].mean()
# Out:
# 252.5

# %%
d["Rate"].mean()
# Out:
# 63.260000000000005

# %%
d["SE"].mean()
# Out:
# 0.38999999999999996

# %%
d=df.loc[df['Region'] == 'HHS Region 05']
d["rownames"].mean()
# Out:
# 256.5

# %%
d["Rate"].mean()
# Out:
# 58.665

# %%
d["SE"].mean()
# Out:
# 0.38

# %%
d=df.loc[df['Region'] == 'HHS Region 06']
d["rownames"].mean()
# Out:
# 260.5

# %%
d["Rate"].mean()
# Out:
# 62.629999999999995

# %%
d["SE"].mean()
# Out:
# 0.5075000000000001

# %%
d=df.loc[df['Region'] == 'HHS Region 07']
d["rownames"].mean()
# Out:
# 264.5

# %%
d["Rate"].mean()
# Out:
# 59.37750000000001

# %%
d["SE"].mean()
# Out:
# 0.6575

# %%
d=df.loc[df['Region'] == 'HHS Region 08']
d["rownames"].mean()
# Out:
# 268.5

# %%
d["Rate"].mean()
# Out:
# 51.7075

# %%
d["SE"].mean()
# Out:
# 0.7849999999999999

# %%
d=df.loc[df['Region'] == 'HHS Region 09']
d["rownames"].mean()
# Out:
# 272.5

# %%
d["Rate"].mean()
# Out:
# 53.11749999999999

# %%
d["SE"].mean()
# Out:
# 0.73

# %%
d=df.loc[df['Region'] == 'HHS Region 10']
d["rownames"].mean()
# Out:
# 276.5

# %%
d["Rate"].mean()
# Out:
# 53.635000000000005

# %%
d["SE"].mean()
# Out:
# 0.7925000000000001

# %%
sns.pairplot(df,hue='Region')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
