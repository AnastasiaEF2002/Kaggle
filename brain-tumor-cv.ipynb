# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex1 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '/kaggle/input/mri-for-brain-tumor-with-bounding-boxes',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '/kaggle/input/mri-for-brain-tumor-with-bounding-boxes',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 5249 files belonging to 2 classes.
# Found 5249 files belonging to 2 classes.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dense(1, activation='sigmoid'),
])

# %%
optimizer = tf.keras.optimizers.Adam(epsilon=0.01)
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=100,
)
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 20s 226ms/step - binary_accuracy: 0.8724 - loss: 0.7373 - val_binary_accuracy: 0.9025 - val_loss: 0.6625
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - binary_accuracy: 0.9032 - loss: 0.6546 - val_binary_accuracy: 0.9025 - val_loss: 0.6321
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.6249 - val_binary_accuracy: 0.9025 - val_loss: 0.6044
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.9032 - loss: 0.5977 - val_binary_accuracy: 0.9025 - val_loss: 0.5790
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.5727 - val_binary_accuracy: 0.9025 - val_loss: 0.5556
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.5498 - val_binary_accuracy: 0.9025 - val_loss: 0.5342
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.5288 - val_binary_accuracy: 0.9025 - val_loss: 0.5146
# Epoch 8/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.5095 - val_binary_accuracy: 0.9025 - val_loss: 0.4966
# Epoch 9/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.4919 - val_binary_accuracy: 0.9025 - val_loss: 0.4802
# Epoch 10/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.4758 - val_binary_accuracy: 0.9025 - val_loss: 0.4651
# Epoch 11/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.9032 - loss: 0.4610 - val_binary_accuracy: 0.9025 - val_loss: 0.4514
# Epoch 12/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.4475 - val_binary_accuracy: 0.9025 - val_loss: 0.4388
# Epoch 13/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.4352 - val_binary_accuracy: 0.9025 - val_loss: 0.4274
# Epoch 14/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.4240 - val_binary_accuracy: 0.9025 - val_loss: 0.4169
# Epoch 15/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.4137 - val_binary_accuracy: 0.9025 - val_loss: 0.4074
# Epoch 16/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.4044 - val_binary_accuracy: 0.9025 - val_loss: 0.3987
# Epoch 17/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3959 - val_binary_accuracy: 0.9025 - val_loss: 0.3908
# Epoch 18/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3881 - val_binary_accuracy: 0.9025 - val_loss: 0.3837
# Epoch 19/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - binary_accuracy: 0.9032 - loss: 0.3811 - val_binary_accuracy: 0.9025 - val_loss: 0.3771
# Epoch 20/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3746 - val_binary_accuracy: 0.9025 - val_loss: 0.3712
# Epoch 21/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3688 - val_binary_accuracy: 0.9025 - val_loss: 0.3658
# Epoch 22/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3635 - val_binary_accuracy: 0.9025 - val_loss: 0.3609
# Epoch 23/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3587 - val_binary_accuracy: 0.9025 - val_loss: 0.3565
# Epoch 24/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.9032 - loss: 0.3543 - val_binary_accuracy: 0.9025 - val_loss: 0.3525
# Epoch 25/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3504 - val_binary_accuracy: 0.9025 - val_loss: 0.3488
# Epoch 26/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3468 - val_binary_accuracy: 0.9025 - val_loss: 0.3456
# Epoch 27/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3436 - val_binary_accuracy: 0.9025 - val_loss: 0.3426
# Epoch 28/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3407 - val_binary_accuracy: 0.9025 - val_loss: 0.3399
# Epoch 29/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3381 - val_binary_accuracy: 0.9025 - val_loss: 0.3375
# Epoch 30/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3357 - val_binary_accuracy: 0.9025 - val_loss: 0.3354
# Epoch 31/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3336 - val_binary_accuracy: 0.9025 - val_loss: 0.3335
# Epoch 32/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3317 - val_binary_accuracy: 0.9025 - val_loss: 0.3317
# Epoch 33/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3300 - val_binary_accuracy: 0.9025 - val_loss: 0.3302
# Epoch 34/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3285 - val_binary_accuracy: 0.9025 - val_loss: 0.3288
# Epoch 35/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3271 - val_binary_accuracy: 0.9025 - val_loss: 0.3276
# Epoch 36/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3259 - val_binary_accuracy: 0.9025 - val_loss: 0.3265
# Epoch 37/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3249 - val_binary_accuracy: 0.9025 - val_loss: 0.3256
# Epoch 38/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3239 - val_binary_accuracy: 0.9025 - val_loss: 0.3247
# Epoch 39/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3231 - val_binary_accuracy: 0.9025 - val_loss: 0.3240
# Epoch 40/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3224 - val_binary_accuracy: 0.9025 - val_loss: 0.3233
# Epoch 41/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3217 - val_binary_accuracy: 0.9025 - val_loss: 0.3228
# Epoch 42/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3211 - val_binary_accuracy: 0.9025 - val_loss: 0.3223
# Epoch 43/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - binary_accuracy: 0.9032 - loss: 0.3207 - val_binary_accuracy: 0.9025 - val_loss: 0.3219
# Epoch 44/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.9032 - loss: 0.3202 - val_binary_accuracy: 0.9025 - val_loss: 0.3215
# Epoch 45/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3199 - val_binary_accuracy: 0.9025 - val_loss: 0.3212
# Epoch 46/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3196 - val_binary_accuracy: 0.9025 - val_loss: 0.3209
# Epoch 47/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3193 - val_binary_accuracy: 0.9025 - val_loss: 0.3207
# Epoch 48/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3191 - val_binary_accuracy: 0.9025 - val_loss: 0.3205
# Epoch 49/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3189 - val_binary_accuracy: 0.9025 - val_loss: 0.3203
# Epoch 50/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3187 - val_binary_accuracy: 0.9025 - val_loss: 0.3202
# Epoch 51/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3186 - val_binary_accuracy: 0.9025 - val_loss: 0.3201
# Epoch 52/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3184 - val_binary_accuracy: 0.9025 - val_loss: 0.3200
# Epoch 53/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3183 - val_binary_accuracy: 0.9025 - val_loss: 0.3199
# Epoch 54/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3183 - val_binary_accuracy: 0.9025 - val_loss: 0.3199
# Epoch 55/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3182 - val_binary_accuracy: 0.9025 - val_loss: 0.3198
# Epoch 56/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3182 - val_binary_accuracy: 0.9025 - val_loss: 0.3198
# Epoch 57/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3181 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 58/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3181 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 59/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3181 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 60/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 61/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 62/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 63/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 64/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 65/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 66/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 67/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3196
# Epoch 68/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3196
# Epoch 69/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3196
# Epoch 70/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3196
# Epoch 71/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3196
# Epoch 72/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 73/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 74/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 75/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 76/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 77/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 78/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 79/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 80/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 81/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 82/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 83/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 84/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 85/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 86/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 87/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 88/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 89/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 90/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 91/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 92/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 93/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 94/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 95/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 96/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 97/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 98/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 99/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197
# Epoch 100/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.9032 - loss: 0.3180 - val_binary_accuracy: 0.9025 - val_loss: 0.3197

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex2 import *

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')

tf.config.run_functions_eagerly(True)

# %%
image_path = '/kaggle/input/mri-for-brain-tumor-with-bounding-boxes/Train/Glioma/images/Te-glTr_0000.jpg'
image = tf.io.read_file(image_path)
image = tf.io.decode_jpeg(image, channels=1)
image = tf.image.resize(image, size=[400, 400])

img = tf.squeeze(image).numpy()
plt.figure(figsize=(6, 6))
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show();

# %%
import learntools.computer_vision.visiontools as visiontools
from learntools.computer_vision.visiontools import edge, bottom_sobel, emboss, sharpen

kernels = [edge, bottom_sobel, emboss, sharpen]
names = ["Edge Detect", "Bottom Sobel", "Emboss", "Sharpen"]

plt.figure(figsize=(12, 12))
for i, (kernel, name) in enumerate(zip(kernels, names)):
    plt.subplot(1, 4, i+1)
    visiontools.show_kernel(kernel)
    plt.title(name)
plt.tight_layout()

# %%
image = tf.image.convert_image_dtype(image, dtype=tf.float32)
image = tf.expand_dims(image, axis=0)
kernel = tf.reshape(kernel, [*kernel.shape, 1, 1])
kernel = tf.cast(kernel, dtype=tf.float32)
conv_fn = tf.nn.conv2d
image_filter = conv_fn(
    input=image,
    filters=kernel,
    strides=1, # or (1, 1)
    padding='SAME',
)

plt.imshow(
    # Reformat for plotting
    tf.squeeze(image_filter)
)
plt.axis('off')
plt.show();

# %%
relu_fn = tf.nn.relu
image_detect = relu_fn(image_filter)

plt.imshow(
    # Reformat for plotting
    tf.squeeze(image_detect)
)
plt.axis('off')
plt.show();

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex3 import *

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib import gridspec
import learntools.computer_vision.visiontools as visiontools

plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
image_path = '/kaggle/input/mri-for-brain-tumor-with-bounding-boxes/Train/Meningioma/images/Tr-meTr_0008.jpg'
image = tf.io.read_file(image_path)
image = tf.io.decode_jpeg(image, channels=1)
image = tf.image.resize(image, size=[400, 400])

# Embossing kernel
kernel = tf.constant([
    [-2, -1, 0],
    [-1, 1, 1],
    [0, 1, 2],
])

# Reformat for batch compatibility.
image = tf.image.convert_image_dtype(image, dtype=tf.float32)
image = tf.expand_dims(image, axis=0)
kernel = tf.reshape(kernel, [*kernel.shape, 1, 1])
kernel = tf.cast(kernel, dtype=tf.float32)

image_filter = tf.nn.conv2d(
    input=image,
    filters=kernel,
    strides=1,
    padding='VALID',
)

image_detect = tf.nn.relu(image_filter)

# Show what we have so far
plt.figure(figsize=(12, 6))
plt.subplot(131)
plt.imshow(tf.squeeze(image), cmap='gray')
plt.axis('off')
plt.title('Input')
plt.subplot(132)
plt.imshow(tf.squeeze(image_filter))
plt.axis('off')
plt.title('Filter')
plt.subplot(133)
plt.imshow(tf.squeeze(image_detect))
plt.axis('off')
plt.title('Detect')
plt.show();

# %%
image_condense = tf.nn.pool(
    input=image_detect,
    window_shape=(2, 2),
    pooling_type='MAX',
    strides=(2, 2),
    padding='SAME',
)
plt.figure(figsize=(8, 6))
plt.subplot(121)
plt.imshow(tf.squeeze(image_detect))
plt.axis('off')
plt.title("Detect (ReLU)")
plt.subplot(122)
plt.imshow(tf.squeeze(image_condense))
plt.axis('off')
plt.title("Condense (MaxPool)")
plt.show();

# %%
REPEATS = 4
SIZE = [64, 64]

# Create a randomly shifted circle
image = visiontools.circle(SIZE, r_shrink=4, val=1)
image = tf.expand_dims(image, axis=-1)
image = visiontools.random_transform(image, jitter=3, fill_method='replicate')
image = tf.squeeze(image)

plt.figure(figsize=(16, 4))
plt.subplot(1, REPEATS+1, 1)
plt.imshow(image, vmin=0, vmax=1)
plt.title("Original\nShape: {}x{}".format(image.shape[0], image.shape[1]))
plt.axis('off')

# Now condense with maximum pooling several times
for i in range(REPEATS):
    ax = plt.subplot(1, REPEATS+1, i+2)
    image = tf.reshape(image, [1, *image.shape, 1])
    image = tf.nn.pool(image, window_shape=(2,2), strides=(2, 2), padding='SAME', pooling_type='MAX')
    image = tf.squeeze(image)
    plt.imshow(image, vmin=0, vmax=1)
    plt.title("MaxPool {}\nShape: {}x{}".format(i+1, image.shape[0], image.shape[1]))
    plt.axis('off')

# %%
feature_maps = [visiontools.random_map([5, 5], scale=0.1, decay_power=3) for _ in range(8)]

gs = gridspec.GridSpec(1, 8, wspace=0.01, hspace=0.01)
plt.figure(figsize=(18, 2))
for i, feature_map in enumerate(feature_maps):
    plt.subplot(gs[i])
    plt.imshow(feature_map, vmin=0, vmax=1)
    plt.axis('off')
plt.suptitle('Feature Maps', size=18, weight='bold', y=1.1)
plt.show()

# reformat for TensorFlow
feature_maps_tf = [tf.reshape(feature_map, [1, *feature_map.shape, 1])
                   for feature_map in feature_maps]

global_avg_pool = tf.keras.layers.GlobalAvgPool2D()
pooled_maps = [global_avg_pool(feature_map) for feature_map in feature_maps_tf]
img = np.array(pooled_maps)[:,:,0].T

plt.imshow(img, vmin=0, vmax=1)
plt.axis('off')
plt.title('Pooled Feature Maps')
plt.show();

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory

model = keras.Sequential([
    # Attach a global average pooling layer after the base
    layers.GlobalAvgPool2D(),
])

# Load dataset
ds = image_dataset_from_directory(
    '/kaggle/input/mri-for-brain-tumor-with-bounding-boxes',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=1,
    shuffle=True,
)

ds_iter = iter(ds)
# Out:
# Found 5249 files belonging to 2 classes.

# %%
pituitary = next(ds_iter)

pituitary_tf = tf.image.resize(pituitary[0], size=[128, 128])
pituitary_features = model(pituitary_tf)
pituitary_features = tf.reshape(pituitary_features, shape=(3, 1))
label = int(tf.squeeze(pituitary[1]).numpy())

plt.figure(figsize=(8, 4))
plt.subplot(121)
plt.imshow(tf.squeeze(pituitary[0]))
plt.axis('off')
plt.title(["Glioma", "Meningioma","No Tumor","Pituitary"][label])
plt.subplot(122)
plt.imshow(pituitary_features)
plt.title('Pooled Feature Maps')
plt.axis('off')
plt.show();
