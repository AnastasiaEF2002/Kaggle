# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

df = pd.DataFrame(pd.read_csv("/kaggle/input/cancer-data-set-registered-vs-death-by-yearsex/cancer_data.csv"))

df
# Out:
#       year    type     sex  numbers         icd_codes cancer_category
# 0     2016    regs  AllSex    24218  C00-C96, D45-D47     All cancers
# 1     2015    regs  AllSex    23380  C00-C96, D45-D47     All cancers
# 2     2014    regs  AllSex    23227  C00-C96, D45-D47     All cancers
# 3     2013    regs  AllSex    22395  C00-C96, D45-D47     All cancers
# 4     2012    regs  AllSex    22062  C00-C96, D45-D47     All cancers
# ...    ...     ...     ...      ...               ...             ...
# 2809  2001  deaths    Male        2               C50          Breast
# 2810  2002  deaths    Male        1               C50          Breast
# 2811  2011  deaths  AllSex        1               C62          Testis
# 2812  2011  deaths    Male        1               C62          Testis
# 2813  2012  deaths    Male        1               C50          Breast
#
# [2814 rows x 6 columns]

# %%
keep_col=['year','type','sex','numbers']
df=df[keep_col]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df,hue='type')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df,hue='sex')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
# draw lineplot
sns.lineplot(x="year", y="numbers", data=df)
 
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
 
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
# draw lineplot
sns.lineplot(x="year", y="numbers", data=df,hue='type')
 
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
 
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
# draw lineplot
sns.lineplot(x="year", y="numbers", data=df,hue='sex')
 
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
 
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
lesion_type_dict = {
    'regs': 1,
    'deaths': 2,
}
df['type'] = df.type.map(lesion_type_dict)
df
# Out:
# /tmp/ipykernel_36/2410561856.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['type'] = df.type.map(lesion_type_dict)
#       year  type     sex  numbers
# 0     2016     1  AllSex    24218
# 1     2015     1  AllSex    23380
# 2     2014     1  AllSex    23227
# 3     2013     1  AllSex    22395
# 4     2012     1  AllSex    22062
# ...    ...   ...     ...      ...
# 2809  2001     2    Male        2
# 2810  2002     2    Male        1
# 2811  2011     2  AllSex        1
# 2812  2011     2    Male        1
# 2813  2012     2    Male        1
#
# [2814 rows x 4 columns]

# %%
lesion_type_dict = {
    'AllSex': 0,
    'Female': 1,
    'Male': 2,
}
df['sex'] = df.sex.map(lesion_type_dict)
df
# Out:
# /tmp/ipykernel_36/3894527768.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sex'] = df.sex.map(lesion_type_dict)
#       year  type  sex  numbers
# 0     2016     1    0    24218
# 1     2015     1    0    23380
# 2     2014     1    0    23227
# 3     2013     1    0    22395
# 4     2012     1    0    22062
# ...    ...   ...  ...      ...
# 2809  2001     2    2        2
# 2810  2002     2    2        1
# 2811  2011     2    0        1
# 2812  2011     2    2        1
# 2813  2012     2    2        1
#
# [2814 rows x 4 columns]

# %%
df.corr()
# Out:
#              year      type       sex   numbers
# year     1.000000 -0.008514  0.000634  0.035677
# type    -0.008514  1.000000 -0.001094 -0.143708
# sex      0.000634 -0.001094  1.000000 -0.077562
# numbers  0.035677 -0.143708 -0.077562  1.000000

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
X = df.drop(['numbers'],axis= 1)
y=df['numbers']
regr = RandomForestRegressor(max_depth=10, random_state=0)
regr.fit(X, y)
print(regr.predict([[3000, 2, 0]]))
# Out:
# [706.95825336]
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
X = df.drop(['numbers'],axis= 1)
y=df['numbers']
regr = RandomForestRegressor(max_depth=10, random_state=0)
regr.fit(X, y)
print(regr.predict([[3000, 1, 0]]))
# Out:
# [1913.86884093]
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
X = df.drop(['numbers'],axis= 1)
y=df['numbers']
regr = RandomForestRegressor(max_depth=10, random_state=0)
regr.fit(X, y)
print(regr.predict([[3000, 2, 1]]))
# Out:
# [387.26758724]
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
X = df.drop(['numbers'],axis= 1)
y=df['numbers']
regr = RandomForestRegressor(max_depth=10, random_state=0)
regr.fit(X, y)
print(regr.predict([[3000, 1, 1]]))
# Out:
# [928.01681607]
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
X = df.drop(['numbers'],axis= 1)
y=df['numbers']
regr = RandomForestRegressor(max_depth=10, random_state=0)
regr.fit(X, y)
print(regr.predict([[3000, 2, 2]]))
# Out:
# [469.49660267]
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
X = df.drop(['numbers'],axis= 1)
y=df['numbers']
regr = RandomForestRegressor(max_depth=10, random_state=0)
regr.fit(X, y)
print(regr.predict([[3000, 1, 2]]))
# Out:
# [1099.29801969]
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
