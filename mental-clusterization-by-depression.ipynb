# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/uncover-global-trends-in-mental-health-disorder/Mental health Depression disorder Data.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Loading the Data
mydata= pd.read_csv('/kaggle/input/uncover-global-trends-in-mental-health-disorder/Mental health Depression disorder Data.csv',encoding='ISO-8859-1')
df = pd.DataFrame(mydata)
df=df[df['Year']=='2017']
df=df.dropna()


# Data Insights
print("===================================# VIEWING AND INSPECTING DATA =================================== \n")
print("---------- # FIRST 5 ROWS # -----------\n",df.head())
print("---------- #  LAST 5 ROWS# # -----------\n",df.tail())
print("---------- #  SUMMARY OF THE DATAFRAME# # -----------\n",df.info())
print("---------- #  STATISTICS OF NUMERICAL COLUMNS# # -----------\n",df.describe())
print("---------- #  SHAPE OF THE DATAFRAME# # -----------\n",df.shape)
print("---------- #  LIST OF COLUMN NAMES# # -----------\n",df.columns)
print("---------- #  DATA TYPES OF COLUMNS# # -----------\n",df.dtypes)

# Data Handling
print("===================================# DATA HANDLING # =================================== \n")
print("---------- # NULL VALUE INFO # -----------\n",df.isnull().sum())

# Selecting only x and y for clustering
X = df[['Depression (%)', 'Alcohol use disorders (%)']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Depression (%)'], df['Alcohol use disorders (%)'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()
# Out:
# <ipython-input-25-2ae830c3979d>:6: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   mydata= pd.read_csv('/kaggle/input/uncover-global-trends-in-mental-health-disorder/Mental health Depression disorder Data.csv',encoding='ISO-8859-1')
# ===================================# VIEWING AND INSPECTING DATA ===================================
#
# ---------- # FIRST 5 ROWS # -----------
#       index          Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 27      27     Afghanistan  AFG  2017          0.166158             0.708089
# 55      55         Albania  ALB  2017          0.201025              0.70448
# 83      83         Algeria  DZA  2017          0.197913             0.818687
# 111    111  American Samoa  ASM  2017          0.248557             0.468305
# 167    167         Andorra  AND  2017          0.263512             0.963331
#
#     Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# ...

# %%
# Selecting only x and y for clustering
X = df[['Depression (%)', 'Schizophrenia (%)']]

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Depression (%)'], df['Schizophrenia (%)'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
X = df[['Depression (%)', 'Bipolar disorder (%)']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Depression (%)'], df['Bipolar disorder (%)'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
X = df[['Depression (%)', 'Eating disorders (%)']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Depression (%)'], df['Eating disorders (%)'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
X = df[['Depression (%)', 'Anxiety disorders (%)']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Depression (%)'], df['Anxiety disorders (%)'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
X = df[['Depression (%)', 'Drug use disorders (%)']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Depression (%)'], df['Drug use disorders (%)'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()
