# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/global-suicide-rates/30_merged_dataset_v00_final.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Loading the Data
mydata= pd.read_csv('/kaggle/input/global-suicide-rates/30_merged_dataset_v00_final.csv',encoding='ISO-8859-1')
df = pd.DataFrame(mydata)
df=df[df['Country']=='Russian Federation']
df=df.dropna()


# Data Insights
print("===================================# VIEWING AND INSPECTING DATA =================================== \n")
print("---------- # FIRST 5 ROWS # -----------\n",df.head())
print("---------- #  LAST 5 ROWS# # -----------\n",df.tail())
print("---------- #  SUMMARY OF THE DATAFRAME# # -----------\n",df.info())
print("---------- #  STATISTICS OF NUMERICAL COLUMNS# # -----------\n",df.describe())
print("---------- #  SHAPE OF THE DATAFRAME# # -----------\n",df.shape)
print("---------- #  LIST OF COLUMN NAMES# # -----------\n",df.columns)
print("---------- #  DATA TYPES OF COLUMNS# # -----------\n",df.dtypes)

# Data Handling
print("===================================# DATA HANDLING # =================================== \n")
print("---------- # NULL VALUE INFO # -----------\n",df.isnull().sum())

# Selecting only x and y for clustering
X = df[['Suicides number', 'Life expectancy']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['Life expectancy'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()
# Out:
# ===================================# VIEWING AND INSPECTING DATA ===================================
#
# ---------- # FIRST 5 ROWS # -----------
#                   Country  Year  Suicides number  Life expectancy  \
# 1083  Russian Federation  2000          56619.0             65.0
# 1084  Russian Federation  2001          56958.0             65.1
# 1085  Russian Federation  2002          55024.0             64.8
# 1086  Russian Federation  2003          51445.0             64.6
# 1087  Russian Federation  2004          49096.0             64.9
#
#       Adult Mortality  Infant deaths  Alcohol  Under-five deaths  HIV/AIDS  \
# 1083             37.0             22    10.18                 26       0.2
# 1084             38.0             21    10.47                 25       0.3
# 1085            313.0             20    10.87                 24       0.3
# 1086            322.0             20    11.32                 22       0.4
# 1087            321.0             19    11.50                 21       0.3
#
#               GDP   Population  Income composition of resources  Schooling
# 1083  1771.586620  146596557.0                            0.709       12.1
# 1084    21.362386   14597683.0                            0.720       12.5
# 1085  2375.594400    1453646.0                            0.727       12.8
# 1086  2975.132778  144648257.0                            0.733       13.2
# 1087   412.372294    1446754.0                            0.741       13.6
# ---------- #  LAST 5 ROWS# # -----------
#                   Country  Year  Suicides number  Life expectancy  \
# 1094  Russian Federation  2011          31038.0             69.4
# 1095  Russian Federation  2012          29643.0             69.6
# 1096  Russian Federation  2013          28690.0             70.0
# 1097  Russian Federation  2014          26541.0             73.0
# 1098  Russian Federation  2015          25432.0             75.0
#
#       Adult Mortality  Infant deaths  Alcohol  Under-five deaths  HIV/AIDS  \
# 1094            242.0             14    11.04                 17       0.3
# 1095            237.0             14    10.99                 16       0.3
# 1096            229.0             14    10.58                 16       0.2
# 1097            225.0             13    10.12                 15       0.1
# 1098            222.0             13    10.12                 15       0.1
#
#                GDP   Population  Income composition of resources  Schooling
# 1094  14212.687000   14296868.0                            0.785       14.0
# 1095  15154.456870   14321676.0                            0.792       14.3
# 1096  15543.676530   14356911.0                            0.799       14.6
# 1097  14125.961000  143819666.0                            0.803       14.9
# 1098   9329.298351    1449687.0                            0.805       15.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 1083 to 1098
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          16 non-null     object
#  1   Year                             16 non-null     int64
#  2   Suicides number                  16 non-null     float64
#  3   Life expectancy                  16 non-null     float64
#  4   Adult Mortality                  16 non-null     float64
#  5   Infant deaths                    16 non-null     int64
#  6   Alcohol                          16 non-null     float64
#  7   Under-five deaths                16 non-null     int64
#  8   HIV/AIDS                         16 non-null     float64
#  9   GDP                              16 non-null     float64
#  10  Population                       16 non-null     float64
#  11  Income composition of resources  16 non-null     float64
#  12  Schooling                        16 non-null     float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 1.8+ KB
# ---------- #  SUMMARY OF THE DATAFRAME# # -----------
#  None
# ---------- #  STATISTICS OF NUMERICAL COLUMNS# # -----------
#                Year  Suicides number  Life expectancy  Adult Mortality  \
# count    16.000000        16.000000        16.000000         16.00000
# mean   2007.500000     40564.125000        67.762500        224.56250
# std       4.760952     10963.178887         3.086935        104.92535
# min    2000.000000     25432.000000        64.600000          3.00000
# 25%    2003.750000     30689.250000        65.000000        224.25000
# 50%    2007.500000     39680.000000        67.400000        249.00000
# 75%    2011.250000     49683.250000        69.450000        289.75000
# max    2015.000000     56958.000000        75.000000        327.00000
#
#        Infant deaths    Alcohol  Under-five deaths   HIV/AIDS           GDP  \
# count      16.000000  16.000000          16.000000  16.000000     16.000000
# mean       16.687500  11.065000          19.312500   0.262500   6545.137359
# std         2.960152   0.657024           3.497023   0.080623   5963.121340
# min        13.000000  10.120000          15.000000   0.100000     21.362386
# 25%        14.000000  10.552500          16.750000   0.200000   1484.054245
# 50%        16.000000  11.045000          18.500000   0.300000   4149.303327
# 75%        19.250000  11.517500          21.250000   0.300000  12257.938025
# max        22.000000  12.190000          26.000000   0.400000  15543.676530
#
#          Population  Income composition of resources  Schooling
# count  1.600000e+01                        16.000000   16.00000
# mean   5.976209e+07                         0.762188   13.74375
# std    6.762227e+07                         0.030588    0.79914
# min    1.428588e+06                         0.709000   12.10000
# 25%    1.106909e+07                         0.739000   13.50000
# 50%    1.435322e+07                         0.765000   13.80000
# 75%    1.430167e+08                         0.786750   14.07500
# max    1.465966e+08                         0.805000   15.00000
# ---------- #  SHAPE OF THE DATAFRAME# # -----------
#  (16, 13)
# ---------- #  LIST OF COLUMN NAMES# # -----------
#  Index(['Country', 'Year', 'Suicides number', 'Life expectancy',
#        'Adult Mortality', 'Infant deaths', 'Alcohol', 'Under-five deaths',
#        'HIV/AIDS', 'GDP', 'Population', 'Income composition of resources',
#        'Schooling'],
#       dtype='object')
# ---------- #  DATA TYPES OF COLUMNS# # -----------
#  Country                             object
# Year                                 int64
# Suicides number                    float64
# Life expectancy                    float64
# Adult Mortality                    float64
# Infant deaths                        int64
# Alcohol                            float64
# Under-five deaths                    int64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object
# ===================================# DATA HANDLING # ===================================
#
# ---------- # NULL VALUE INFO # -----------
#  Country                            0
# Year                               0
# Suicides number                    0
# Life expectancy                    0
# Adult Mortality                    0
# Infant deaths                      0
# Alcohol                            0
# Under-five deaths                  0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
# Selecting only x and y for clustering
X = df[['Suicides number', 'Adult Mortality']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['Adult Mortality'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
# Selecting only x and y for clustering
X = df[['Suicides number', 'Infant deaths']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['Infant deaths'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
# Selecting only x and y for clustering
X = df[['Suicides number', 'Alcohol']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['Alcohol'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
# Selecting only x and y for clustering
X = df[['Suicides number', 'Under-five deaths']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['Under-five deaths'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
# Selecting only x and y for clustering
X = df[['Suicides number', 'HIV/AIDS']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['HIV/AIDS'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
# Selecting only x and y for clustering
X = df[['Suicides number', 'GDP']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['GDP'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
# Selecting only x and y for clustering
X = df[['Suicides number', 'Population']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['Population'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
# Selecting only x and y for clustering
X = df[['Suicides number', 'Income composition of resources']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['Income composition of resources'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
#Selecting only x and y for clustering
X = df[['Suicides number', 'Schooling']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['Schooling'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
#Selecting only x and y for clustering
X = df[['Suicides number', 'Year']]

# Applying K-Means clustering (choosing 3 clusters as an assumption)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Suicides number'], df['Year'], c=df['cluster'], cmap='viridis', alpha=0.6, edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('K-Means Clustering of Data')
plt.legend()
plt.show()

# %%
df
# Out:
#                  Country  Year  Suicides number  Life expectancy  \
# 1083  Russian Federation  2000          56619.0             65.0
# 1084  Russian Federation  2001          56958.0             65.1
# 1085  Russian Federation  2002          55024.0             64.8
# 1086  Russian Federation  2003          51445.0             64.6
# 1087  Russian Federation  2004          49096.0             64.9
# 1088  Russian Federation  2005          45802.0             65.0
# 1089  Russian Federation  2006          42614.0             66.4
# 1090  Russian Federation  2007          41149.0             67.3
# 1091  Russian Federation  2008          38211.0             67.5
# 1092  Russian Federation  2009          37408.0             68.2
# 1093  Russian Federation  2010          33356.0             68.4
# 1094  Russian Federation  2011          31038.0             69.4
# 1095  Russian Federation  2012          29643.0             69.6
# 1096  Russian Federation  2013          28690.0             70.0
# 1097  Russian Federation  2014          26541.0             73.0
# 1098  Russian Federation  2015          25432.0             75.0
#
#       Adult Mortality  Infant deaths  Alcohol  Under-five deaths  HIV/AIDS  \
# 1083             37.0             22    10.18                 26       0.2
# 1084             38.0             21    10.47                 25       0.3
# 1085            313.0             20    10.87                 24       0.3
# 1086            322.0             20    11.32                 22       0.4
# 1087            321.0             19    11.50                 21       0.3
# 1088            327.0             18    11.57                 20       0.3
# 1089              3.0             17    11.79                 20       0.3
# 1090            282.0             16    12.19                 19       0.3
# 1091            278.0             16    12.04                 18       0.3
# 1092            261.0             15    11.21                 18       0.3
# 1093            256.0             15    11.05                 17       0.2
# 1094            242.0             14    11.04                 17       0.3
# 1095            237.0             14    10.99                 16       0.3
# 1096            229.0             14    10.58                 16       0.2
# 1097            225.0             13    10.12                 15       0.1
# 1098            222.0             13    10.12                 15       0.1
#
#                GDP   Population  Income composition of resources  Schooling  \
# 1083   1771.586620  146596557.0                            0.709       12.1
# 1084     21.362386   14597683.0                            0.720       12.5
# 1085   2375.594400    1453646.0                            0.727       12.8
# 1086   2975.132778  144648257.0                            0.733       13.2
# 1087    412.372294    1446754.0                            0.741       13.6
# 1088   5323.473877  143518523.0                            0.748       13.7
# 1089    692.194398   14349528.0                            0.754       13.8
# 1090    911.253850    1428588.0                            0.761       13.8
# 1091  11635.263700   14274235.0                            0.769       13.9
# 1092   8562.895980  142785342.0                            0.776       14.0
# 1093   1674.987710  142849449.0                            0.773       13.7
# 1094  14212.687000   14296868.0                            0.785       14.0
# 1095  15154.456870   14321676.0                            0.792       14.3
# 1096  15543.676530   14356911.0                            0.799       14.6
# 1097  14125.961000  143819666.0                            0.803       14.9
# 1098   9329.298351    1449687.0                            0.805       15.0
#
#       cluster
# 1083        2
# 1084        2
# 1085        2
# 1086        2
# 1087        2
# 1088        0
# 1089        0
# 1090        0
# 1091        0
# 1092        0
# 1093        1
# 1094        1
# 1095        1
# 1096        1
# 1097        1
# 1098        1
