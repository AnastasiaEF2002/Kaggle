# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

df = pd.DataFrame(pd.read_csv("/kaggle/input/metallica-studio-tracks-with-spotify-data/MetallicaAllTracks.csv"))

df
# Out:
#                                                  Track  \
# 0                                           72 Seasons
# 1                                       Shadows Follow
# 2                                    Screaming Suicide
# 3                               Sleepwalk My Life Away
# 4                                       You Must Burn!
# ..                                                 ...
# 360  No Remorse (Live at Espace Balard, Paris, Fran...
# 361  Ride The Lightning (Live at Espace Balard, Par...
# 362  Motorbreath (Live at Espace Balard, Paris, Fra...
# 363  (Anesthesia) – Pulling Teeth (Live at Espace B...
# 364  Whiplash (Live at Espace Balard, Paris, France...
#
#                               Album    Year Duration  Time_Signature  \
# 0                        72 Seasons  2023.0     7:39               4
# 1                        72 Seasons  2023.0     6:11               4
# 2                        72 Seasons  2023.0     5:30               4
# ...

# %%
keep_col = ['Year','Time_Signature','Danceability','Energy','Key','Loudness','Mode','Speechiness','Acousticness','Instrumentalness','Liveness','Valence','Tempo','Popularity']
f = df[keep_col]
f.corr()
# Out:
#                       Year  Time_Signature  Danceability    Energy       Key  \
# Year              1.000000        0.059952     -0.111911  0.363867  0.041727
# Time_Signature    0.059952        1.000000     -0.045866  0.373809  0.085342
# Danceability     -0.111911       -0.045866      1.000000 -0.210403  0.012989
# Energy            0.363867        0.373809     -0.210403  1.000000 -0.000233
# Key               0.041727        0.085342      0.012989 -0.000233  1.000000
# Loudness          0.701078        0.231597      0.004081  0.614896  0.009066
# Mode              0.026800        0.055241     -0.065490  0.084527 -0.208387
# Speechiness      -0.329107       -0.109683     -0.278324  0.114016 -0.032836
# Acousticness     -0.194459       -0.233488     -0.123038 -0.409209 -0.011366
# Instrumentalness -0.366282        0.034418     -0.217059 -0.080237  0.024439
# Liveness         -0.096480       -0.113845     -0.419419  0.021876 -0.107487
# ...

# %%
f=f.dropna()
f.corr()
# Out:
#                       Year  Time_Signature  Danceability    Energy       Key  \
# Year              1.000000        0.059952     -0.111911  0.363867  0.041727
# Time_Signature    0.059952        1.000000     -0.112498  0.388575  0.132623
# Danceability     -0.111911       -0.112498      1.000000 -0.365071 -0.016091
# Energy            0.363867        0.388575     -0.365071  1.000000 -0.035610
# Key               0.041727        0.132623     -0.016091 -0.035610  1.000000
# Loudness          0.701078        0.151383     -0.273997  0.650307 -0.075808
# Mode              0.026800       -0.067298     -0.048848  0.042860 -0.160504
# Speechiness      -0.329107        0.084780     -0.482061  0.297853 -0.039647
# Acousticness     -0.194459       -0.343431      0.110573 -0.437639  0.022579
# Instrumentalness -0.366282        0.088763     -0.161433 -0.115881  0.085621
# Liveness         -0.096480       -0.181970      0.009105 -0.095565 -0.111471
# ...

# %%
f
# Out:
#        Year  Time_Signature  Danceability  Energy  Key  Loudness  Mode  \
# 0    2023.0               4         0.193   0.983    9    -3.929     1
# 1    2023.0               4         0.313   0.979   11    -3.907     1
# 2    2023.0               4         0.425   0.972    4    -3.448     0
# 3    2023.0               4         0.430   0.950   11    -4.203     1
# 4    2023.0               4         0.397   0.958    6    -3.088     0
# ..      ...             ...           ...     ...  ...       ...   ...
# 340  1983.0               4         0.386   0.911    4    -6.474     0
# 341  1983.0               4         0.212   0.973    2    -5.307     1
# 342  1983.0               4         0.296   0.915    9    -5.979     1
# 343  1983.0               4         0.439   0.963    9    -5.508     1
# 344  1983.0               4         0.166   0.956    9    -5.307     1
#
#      Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  3518.216186470148
# mean_absolute_error :  47.42407263114034

# %%
model.intercept_
# Out:
# 9574.90497373976

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [-4.733, -0.0, 192.953, 100.417, -1.212, 27.77, -15.464, -10.552, 7.185, -6.686, 16.888, -49.557, -0.496]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity','Year'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  1724.5857729960287
# mean_absolute_error :  31.537772270615623

# %%
model.intercept_
# Out:
# -273.9618613370149

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [-0.0, -74.245, 284.307, 0.614, -13.054, -5.513, -407.167, 3836.219, -32.208, 211.134, -34.534, 0.184]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity','Year','Time_Signature'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  1724.5857729728814
# mean_absolute_error :  31.537772270364236

# %%
model.intercept_
# Out:
# -273.96186135107627

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [-74.245, 284.307, 0.614, -13.054, -5.513, -407.167, 3836.219, -32.208, 211.134, -34.534, 0.184]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity','Year','Time_Signature','Key'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  1487.6437367984297
# mean_absolute_error :  29.451010616619374

# %%
model.intercept_
# Out:
# -262.9268268146481

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [-63.947, 272.816, -13.165, -4.311, -364.549, 3843.476, -25.691, 181.144, -37.268, 0.184]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity','Year','Time_Signature','Key','Mode'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  808.3131928682983
# mean_absolute_error :  21.77649369534422

# %%
model.intercept_
# Out:
# -220.67145156230424

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [-42.511, 225.368, -11.413, -295.861, 1912.668, -19.908, 129.748, -27.033, 0.179]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity','Year','Time_Signature','Key','Mode','Instrumentalness'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  498.6906310289854
# mean_absolute_error :  17.46801647063422

# %%
model.intercept_
# Out:
# -143.3302214456455

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [-20.432, 153.679, -9.03, -178.201, 3.433, 77.503, -25.223, 0.107]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity','Year','Time_Signature','Key','Mode','Instrumentalness','Valence'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  438.884347437368
# mean_absolute_error :  13.04123537306824

# %%
model.intercept_
# Out:
# -51.697849920967606

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [-3.507, 64.458, -4.984, -33.508, -1721.897, 29.97, 0.058]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity','Year','Time_Signature','Key','Mode','Instrumentalness','Valence','Danceability'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  451.48199306046075
# mean_absolute_error :  12.785886681945861

# %%
model.intercept_
# Out:
# -45.03677798023609

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [58.046, -4.704, -18.698, -1868.563, 24.969, 0.052]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity','Year','Time_Signature','Key','Mode','Instrumentalness','Valence','Danceability','Loudness'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  113.31942922355738
# mean_absolute_error :  8.356661287452678

# %%
model.intercept_
# Out:
# 76.85118830541015

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [-29.892, 91.636, -403.83, -17.513, -0.075]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = f.drop(['Popularity','Year','Time_Signature','Key','Mode','Instrumentalness','Valence','Danceability','Loudness','Energy'],axis= 1)
y = f['Popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  91.79842857613465
# mean_absolute_error :  7.604900134714858

# %%
model.intercept_
# Out:
# 49.69974591434852

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [65.553, 275.223, -5.863, -0.076]

# %%
X
# Out:
#      Speechiness  Acousticness  Liveness    Tempo
# 0         0.0591      0.000040    0.0645  168.193
# 1         0.0462      0.000121    0.2610  178.884
# 2         0.0450      0.000024    0.2390  101.125
# 3         0.0340      0.000017    0.1030  124.931
# 4         0.0341      0.000122    0.0378   85.836
# ..           ...           ...       ...      ...
# 340       0.0956      0.000608    0.1350  158.045
# 341       0.3220      0.000842    0.0921  159.381
# 342       0.1630      0.000297    0.3620   96.715
# 343       0.2770      0.036400    0.0784  140.805
# 344       0.1450      0.000081    0.1180  176.217
#
# [119 rows x 4 columns]
